# %%
import cinetica

# %%
cinetica.exponetial_fit(5.,3.,4.,5.)
# Out:
# 5.000000006183461

# %%
import numpy as np

# %%
x= np.linspace(0,5)
y = np.sin(x)+np.random.normal(size=x.size)
y_fit= np.sin(x)

# %%
cinetica.plot_ajuste(x,y, y_fit)
